# %% [markdown]
# # PydanticAI 입문 가이드
#
# 이 노트북은 `analysis_agent.ipynb`, `automation_agent.ipynb`, `planner_agent.ipynb`에서 사용하는 **PydanticAI**의 핵심 개념을 단계별로 설명합니다.
#
# ## PydanticAI란?
#
# PydanticAI는 LLM 기반 애플리케이션을 만들기 위한 Python 프레임워크입니다.
#
# 핵심 아이디어는 간단합니다:
# 1. **Agent** — LLM을 감싸는 객체. "누구에게 어떤 일을 시킬지" 정의
# 2. **Instructions** — Agent에게 주는 시스템 프롬프트 (역할, 규칙)
# 3. **Structured Output** — LLM 응답을 Pydantic 모델로 강제하여 JSON 형태로 받기
# 4. **Tools** — Agent가 호출할 수 있는 Python 함수 (검색, API 호출 등)
#
# 아래에서 하나씩 실습해보겠습니다.

# %% [markdown]
# ## 1단계: 환경 설정
#
# 먼저 API 키를 로드하고 필요한 라이브러리를 임포트합니다.
#
# - `dotenv`: `.env` 파일에 저장된 `OPENAI_API_KEY`를 환경변수로 로드
# - `pydantic`: 구조화된 출력 스키마를 정의하는 데이터 검증 라이브러리
# - `pydantic_ai`: LLM Agent를 만들고 실행하는 프레임워크

# %%
# .env 파일에서 OPENAI_API_KEY 환경변수 로드
from dotenv import load_dotenv
load_dotenv()

from pydantic import BaseModel   # 구조화된 출력 스키마 정의용
from pydantic_ai import Agent    # LLM 기반 Agent 프레임워크

# %% [markdown]
# ## 2단계: 가장 간단한 Agent
#
# PydanticAI에서 Agent를 만드는 최소 코드는 단 2줄입니다.
#
# ```python
# agent = Agent("openai:gpt-5.4")          # 1) Agent 생성 (사용할 LLM 지정)
# result = await agent.run("안녕하세요!")    # 2) 실행
# ```
#
# - `Agent(모델명)`: 어떤 LLM을 사용할지 지정합니다
# - `await agent.run(프롬프트)`: Agent에게 메시지를 보내고 응답을 받습니다
# - `result.output`: 응답 텍스트가 담겨 있습니다
#
# > **주의:** Jupyter 노트북에서는 `await agent.run()`을 사용합니다.
# > 일반 Python 스크립트에서는 `agent.run_sync()`를 사용하면 됩니다.

# %%
# 가장 간단한 Agent: 모델만 지정하고 바로 실행
simple_agent = Agent("openai:gpt-5.4")

# Agent에게 메시지를 보내고 응답 받기
result = await simple_agent.run("PydanticAI를 한 줄로 설명해줘.")

# result.output에 LLM의 응답 텍스트가 담겨 있음
print(result.output)
# Out:
# PydanticAI는 **Pydantic의 타입 검증 강점을 활용해 LLM 애플리케이션을 더 안전하고 구조적으로 만들 수 있게 해주는 Python용 AI 에이전트 프레임워크**입니다.

# %% [markdown]
# ## 3단계: Instructions (시스템 프롬프트)
#
# `instructions` 파라미터로 Agent에게 **역할과 규칙**을 부여할 수 있습니다.
# 이는 ChatGPT의 "system prompt"와 같은 역할입니다.
#
# ```python
# agent = Agent(
#     "openai:gpt-5.4",
#     instructions="너는 친절한 요리사야. 모든 답변을 요리 비유로 해줘."
# )
# ```
#
# `instructions`가 있으면 Agent는 매 요청마다 이 규칙을 따릅니다.

# %%
# instructions로 Agent에게 역할 부여
chef_agent = Agent(
    "openai:gpt-5.4",
    instructions="너는 친절한 요리사야. 모든 답변을 요리 비유로 설명해줘. 한국어로 답변.",
)

# 같은 질문이라도 instructions에 따라 답변 스타일이 달라짐
result = await chef_agent.run("Agent의 RAG 구성과 VectorDB를 활용한 질의 처리에 대해 설명해줘.")
print(result.output)
# Out:
# 좋아요. 이걸 **“똑똑한 요리사와 주방 시스템”** 비유로 설명해볼게요.
#
# ---
#
# ## 1. Agent의 RAG 구성이란?
#
# RAG는 **Retrieval-Augmented Generation**의 줄임말이에요.
# 요리로 비유하면,
#
# - **LLM(Agent)** = 요리사
# - **사용자 질문** = 손님의 주문
# - **사전 학습 지식** = 요리사가 원래 알고 있던 기본 레시피
# - **외부 문서/데이터베이스** = 주방 선반에 꽂힌 최신 레시피북, 재고표, 매장 운영 매뉴얼
# - **Retrieval(검색)** = 요리사가 주문에 맞는 레시피북 페이지를 찾아보는 과정
# - **Generation(생성)** = 찾아본 내용을 바탕으로 손님에게 맞춤 요리를 완성하는 과정
#
# 즉, RAG는
# **“요리사가 자기 기억만 믿지 않고, 필요할 때 레시피북을 꺼내 확인한 뒤 더 정확한 요리를 내놓는 방식”**이에요.
#
# ---
#
# ## 2. 왜 그냥 LLM만 쓰지 않고 RAG를 붙일까?
#
# 기본 LLM만 쓰는 건,
# 요리사가 **예전에 배운 레시피만 기억해서 요리하는 것**과 비슷해요.
#
# 문제는:
#
# - 최신 정보가 반영되지 않을 수 있고
# - 특정 회사 내부 문서처럼 원래 모르는 재료는 답하기 어렵고
# - 가끔은 없는 레시피를 그럴듯하게 지어낼 수도 있어요
#
# RAG를 붙이면:
#
# - 최신 문서 검색 가능
# - 사내 문서, 제품 매뉴얼, 정책 문서 활용 가능
# - 답변 근거를 문서에서 가져와 신뢰도 향상
#
# 즉, **기억에만 의존하던 요리사가, 주문마다 주방 자료를 확인하는 프로 요리사**가 되는 거예요.
#
# ---
#
# ## 3. RAG의 전체 구성
#
# RAG 구성은 보통 아래 순서로 돌아가요.
#
# ### 3-1. 문서 수집
# 먼저 주방에 레시피북을 모아둬야 해요.
#
# 예:
# - PDF 매뉴얼
# - 위키 문서
# - FAQ
# - 정책 문서
# - 이메일/보고서
#
# 이건 마치 **여러 요리책과 재고 장부를 한 주방에 모으는 작업**이에요.
#
# ---
#
# ### 3-2. 문서 분할(Chunking)
# 문서를 통째로 넣으면 너무 길어요.
# 그래서 문서를 작은 조각으로 나눠요.
#
# 예:
# - 챕터 단위
# - 문단 단위
# - 의미 단위
#
# 이건 **거대한 레시피북을 페이지별, 요리 단계별로 잘라 정리하는 것**과 같아요.
#
# 왜 필요하냐면,
# 손님이 “파스타 소스 만드는 법”을 물었는데 책 한 권 전체를 펼칠 필요는 없잖아요.
# 딱 관련된 페이지 몇 장만 보면 되니까요.
#
# ---
#
# ### 3-3. 임베딩(Embedding)
# 각 문서 조각을 숫자 벡터로 바꿔요.
# 이건 컴퓨터가 의미를 이해할 수 있도록 바꾸는 과정이에요.
#
# 요리 비유로 하면,
# 각 레시피에 대해
# **“매운맛 정도, 국물 여부, 재료 스타일, 조리 방식”** 같은 특성을 좌표로 표시하는 것과 비슷해요.
#
# 예를 들어:
# - 김치찌개 레시피와 된장찌개 레시피는 가까운 선반에
# - 초밥 레시피는 멀리 떨어진 선반에
#
# 즉, **의미가 비슷한 문서끼리 가까운 위치에 놓이게 만드는 작업**이에요.
#
# ---
#
# ### 3-4. VectorDB 저장
# 임베딩된 문서 조각들을 **VectorDB**에 저장해요.
#
# VectorDB는 요리로 비유하면
# **“재료의 맛과 특징 기준으로 정리된 초고속 주방 창고”**예요.
#
# 일반 DB가 “이름표 순서”로 재료를 찾는 창고라면,
# VectorDB는 “비슷한 맛/용도” 기준으로 재료를 빨리 꺼낼 수 있는 창고예요.
#
# 예:
# - “매콤한 국물 요리”와 비슷한 레시피 찾기
# - “환불 정책과 관련된 설명”과 비슷한 문서 찾기
#
# ---
#
# ## 4. VectorDB를 활용한 질의 처리 과정
#
# 이제 손님이 주문했다고 생각해볼게요.
#
# 질문:
# > “우리 서비스의 환불 정책은 어떻게 되나요?”
#
# 이때 주방에서는 이렇게 돌아가요.
#
# ---
#
# ### 4-1. 사용자 질문 수신
# 손님이 주문서를 냅니다.
# 요리사는 질문을 받아요.
#
# ---
#
# ### 4-2. 질문 임베딩
# 질문도 문서와 같은 방식으로 임베딩해요.
#
# 즉,
# “환불 정책은 어떻게 되나요?”라는 주문도
# 주방 시스템이 이해할 수 있는 **의미 좌표**로 바뀌어요.
#
# 이건 **손님의 입맛 요청을 맛 지도 위 한 점으로 표시하는 것**과 같아요.
#
# ---
#
# ### 4-3. VectorDB에서 유사 문서 검색
# 질문의 벡터와 가장 가까운 문서 조각들을 찾아요.
#
# 예:
# - 환불 규정 1조
# - 구독 해지 정책 문단
# - 예외 처리 FAQ
#
# 이 과정은
# **“손님의 주문과 가장 비슷한 레시피 카드들을 주방 선반에서 빠르게 꺼내오는 작업”**이에요.
#
# 검색 방식은 보통:
# - Top-K 검색: 가장 비슷한 문서 K개 선택
# - Similarity Search: 코사인 유사도 등으로 가까운 것 찾기
# - Hybrid Search: 키워드 검색 + 벡터 검색 같이 사용
#
# ---
#
# ### 4-4. 검색 결과 재정렬(Optional)
# 처음 가져온 문서가 완벽하지 않을 수 있어요.
# 그래서 reranker를 써서 더 관련도 높은 순서로 다시 정렬하기도 해요.
#
# 이건
# **보조 요리사가 여러 레시피 후보를 가져오면, 메인 셰프가 그중 가장 적합한 걸 다시 고르는 과정**이에요.
#
# ---
#
# ### 4-5. 프롬프트 구성
# 이제 Agent는 이렇게 재료를 갖추게 돼요:
#
# - 손님의 질문
# - 검색된 관련 문서 조각
# - 시스템 지시사항
#
# 이걸 하나의 프롬프트로 묶어요.
#
# 즉,
# **주문서 + 참고 레시피 + 매장 조리 원칙**을 셰프 앞 작업대에 올려두는 거예요.
#
# ---
#
# ### 4-6. LLM이 답변 생성
# LLM은 검색된 문서를 참고해서 답변을 만들어요.
#
# 중요한 점은,
# 이제 요리사는 자기 기억만으로 요리하는 게 아니라
# **방금 꺼낸 레시피북 내용을 근거로 요리한다**는 거예요.
#
# 그래서 답변이:
# - 더 정확하고
# - 더 최신이고
# - 더 근거 기반이 될 수 있어요
#
# ---
#
# ## 5. Agent가 붙으면 뭐가 더 좋아질까?
#
# RAG만 있으면 기본적으로는
# “찾고, 읽고, 답한다” 정도예요.
#
# Agent가 붙으면 요리사가 더 능동적으로 움직여요.
#
# ### Agent의 역할
# Agent는 단순 답변 생성기가 아니라,
# **“주방 전체를 운영하는 총괄 셰프”** 같은 존재예요.
#
# 할 수 있는 일:
# - 질문을 분석
# - 검색이 필요한지 판단
# - 어떤 도구를 쓸지 선택
# - 여러 번 검색
# - 결과가 부족하면 다시 검색
# - 계산기, API, DB 등 다른 도구와 연동
# - 최종 답변 조립
#
# 즉, Agent는
# **“이 주문은 국물부터 확인해야겠네, 재고도 보고, 레시피북도 두 권 뒤져보고, 마지막에 plating까지 하자”**
# 처럼 단계적으로 일해요.
#
# ---
#
# ## 6. Agent + RAG 질의 처리 흐름
#
# 예를 들어 손님이 이렇게 묻는다고 해볼게요.
#
# > “우리 회사 출장비 환급 규정과, 해외 출장 시 예외 조건도 알려줘.”
#
# 이 질문은 한 번에 끝나지 않을 수 있어요.
# Agent는 이렇게 움직일 수 있어요.
#
# 1. 질문 분석
#    - “출장비 환급 규정”과 “해외 출장 예외 조건” 두 가지 하위 작업으로 분리
#
# 2. 첫 번째 검색
#    - 출장비 규정 문서 검색
#
# 3. 두 번째 검색
#    - 해외 출장 예외 정책 검색
#
# 4. 부족한 정보 확인
#    - 최신 개정본이 필요한지 추가 검색
#
# 5. 결과 통합
#    - 두 정책을 합쳐서 구조화된 답변 생성
#
# 이건
# **한 접시에 메인 요리와 사이드 요리를 함께 내기 위해, 여러 조리대를 오가며 준비하는 셰프**와 같아요.
#
# ---
#
# ## 7. VectorDB의 핵심 가치
#
# VectorDB가 중요한 이유는
# “정확히 같은 단어”가 아니라
# **“비슷한 의미”**를 찾는 데 강하기 때문이에요.
#
# 예를 들어 문서에는 “구독 해지 후 환급”이라고 쓰여 있고,
# 사용자는 “환불”이라고 물을 수 있어요.
#
# 일반 키워드 검색은 놓칠 수 있지만,
# VectorDB는 의미가 비슷하면 찾아낼 가능성이 커요.
#
# 요리로 말하면,
# 손님이 “시원한 국물”을 원했을 때
# 메뉴판에 정확히 그 단어가 없어도
# **냉국, 맑은 해장국, 동치미국물** 같은 비슷한 성격의 요리를 추천할 수 있는 주방 시스템**이에요.
#
# ---
#
# ## 8. 실무에서 고려할 점
#
# RAG 요리를 잘하려면 재료 손질이 중요해요.
#
# ### 8-1. Chunking 품질
# 문서를 너무 작게 자르면 맥락이 끊기고,
# 너무 크게 자르면 검색 정확도가 떨어져요.
#
# 즉,
# **재료를 너무 잘게 다지면 식감이 사라지고, 너무 크게 썰면 익지 않는 것**과 같아요.
#
# ---
#
# ### 8-2. 임베딩 모델 선택
# 어떤 임베딩 모델을 쓰느냐에 따라
# 검색 품질이 달라져요.
#
# 이건
# **같은 재료라도 어떤 칼과 어떤 손질법을 쓰느냐에 따라 맛이 달라지는 것**과 비슷해요.
#
# ---
#
# ### 8-3. 메타데이터 활용
# 문서 출처, 날짜, 부서, 버전 등을 함께 저장하면 좋아요.
#
# 예:
# - `source: HR_policy.pdf`
# - `date: 2025-01-10`
# - `department: Finance`
#
# 이건
# **레시피 카드에 작성자, 작성일, 버전, 메뉴 종류를 같이 적어두는 것**과 같아요.
# 그래야 최신 레시피를 우선 꺼낼 수 있어요.
#
# ---
#
# ### 8-4. Hybrid Search
# 벡터 검색만으로 부족할 때는 키워드 검색과 같이 써요.
#
# 예:
# - 숫자, 코드, 상품명 같은 정확 일치가 중요할 때
# - 정책 문서 조항 번호가 중요할 때
#
# 이건
# **“맛으로 비슷한 요리 찾기”와 “정확한 메뉴명 찾기”를 같이 하는 방식**이에요.
#
# ---
#
# ### 8-5. Hallucination 방지
# 검색 결과가 없거나 약하면, Agent가 모른다고 말하거나 추가 검색해야 해요.
#
# 즉,
# 없는 재료인데 있는 척 요리하면 안 돼요.
# **좋은 셰프는 재료가 없으면 없다고 말하고, 대체 가능한지 확인**하죠.
#
# ---
#
# ## 9. 한 줄로 정리하면
#
# - **RAG** = 요리사가 레시피북을 찾아보고 요리하는 방식
# - **VectorDB** = 의미가 비슷한 레시피를 빠르게 찾는 주방 창고
# - **Agent** = 어떤 레시피를 찾고 어떤 도구를 쓸지 판단하는 총괄 셰프
#
# 즉,
# **Agent + RAG + VectorDB**는
# “총괄 셰프가 초고속 레시피 창고를 활용해, 손님 주문에 맞는 근거 있는 요리를 만들어내는 지능형 주방 시스템”이라고 볼 수 있어요.
#
# ---
#
# 원하시면 다음엔
# 1. **RAG 아키텍처를 그림처럼 단계별로 정리**하거나
# 2. **LangChain/LlamaIndex 기준 구현 흐름**이나
# 3. **VectorDB(Pinecone, Weaviate, FAISS, Milvus) 비교**까지 이어서 설명해드릴게요.

# %% [markdown]
# ## 4단계: Structured Output (구조화된 출력)
#
# 기본 Agent는 자유 텍스트를 반환합니다. 하지만 실무에서는 **정해진 형식의 데이터**가 필요합니다.
#
# `output_type`에 Pydantic 모델을 지정하면, LLM이 자유 텍스트 대신 **해당 스키마에 맞는 데이터**를 반환합니다.
#
# ### 왜 필요할까요?
#
# | 자유 텍스트 | 구조화된 출력 |
# |---|---|
# | "이 영화는 8점입니다" | `{"title": "...", "score": 8, "genre": "SF"}` |
# | 후속 처리 어려움 | DB 저장, API 연동 바로 가능 |
#
# ### 사용법
#
# ```python
# class Movie(BaseModel):        # 1) 원하는 출력 형식을 Pydantic 모델로 정의
#     title: str
#     score: int
#
# agent = Agent(
#     "openai:gpt-5.4",
#     output_type=Movie,          # 2) Agent에 output_type으로 지정
# )
# result = await agent.run(...)
# movie = result.output           # 3) result.output이 Movie 타입으로 반환됨
# print(movie.title)              #    → 속성으로 바로 접근 가능
# ```
#
# > **실전 활용:** `analysis_agent.ipynb`에서 `CodeReview` 모델로 코드 리뷰 결과를, `automation_agent.ipynb`에서 `DailyReport` 모델로 일일 보고서를 구조화합니다.

# %%
# Step 1) 원하는 출력 형식을 Pydantic 모델로 정의
class MovieReview(BaseModel):
    title: str       # 영화 제목
    score: int       # 평점 (1~10)
    pros: list[str]  # 장점 목록
    cons: list[str]  # 단점 목록


# Step 2) output_type으로 지정 → LLM이 반드시 이 형식으로 응답
review_agent = Agent(
    "openai:gpt-5.4",
    output_type=MovieReview,
    instructions="영화 평론가로서 요청받은 영화를 평가. 한국어로 작성.",
)

# Step 3) 실행 → result.output이 MovieReview 타입
result = await review_agent.run("어벤져스를 평가해주세요.")
review = result.output

# Pydantic 모델이므로 속성으로 바로 접근 가능
print(f"제목: {review.title}")
print(f"평점: {review.score}/10")
print(f"장점: {', '.join(review.pros)}")
print(f"단점: {', '.join(review.cons)}")
# Out:
# 제목: 어벤져스
# 평점: 8/10
# 장점: 마블 히어로들이 한자리에 모이는 팀업의 쾌감이 뛰어나다., 각 캐릭터의 개성을 살린 대사와 상호작용이 큰 재미를 준다., 뉴욕 전투를 중심으로 한 액션 연출이 시원하고 대중성이 강하다.
# 단점: 서사가 비교적 단순해 예상 가능한 전개로 흐르는 부분이 있다., 일부 캐릭터는 비중이 제한적이라 깊이 있는 감정선이 부족하다., 마블 시네마틱 유니버스의 사전 지식이 있으면 더 잘 즐길 수 있다는 진입장벽이 있다.

# %%
review
# Out:
# MovieReview(title='어벤져스', score=8, pros=['마블 히어로들이 한자리에 모이는 팀업의 쾌감이 뛰어나다.', '각 캐릭터의 개성을 살린 대사와 상호작용이 큰 재미를 준다.', '뉴욕 전투를 중심으로 한 액션 연출이 시원하고 대중성이 강하다.'], cons=['서사가 비교적 단순해 예상 가능한 전개로 흐르는 부분이 있다.', '일부 캐릭터는 비중이 제한적이라 깊이 있는 감정선이 부족하다.', '마블 시네마틱 유니버스의 사전 지식이 있으면 더 잘 즐길 수 있다는 진입장벽이 있다.'])

# %%
review.title
# Out:
# '어벤져스'

# %%
review.pros
# Out:
# ['마블 히어로들이 한자리에 모이는 팀업의 쾌감이 뛰어나다.',
#  '각 캐릭터의 개성을 살린 대사와 상호작용이 큰 재미를 준다.',
#  '뉴욕 전투를 중심으로 한 액션 연출이 시원하고 대중성이 강하다.']

# %% [markdown]
# ## 5단계: Tools (도구)
#
# Agent에게 **Python 함수를 도구로 등록**하면, LLM이 필요할 때 해당 함수를 호출할 수 있습니다.
#
# ### 왜 필요할까요?
#
# LLM은 혼자서는 다음을 할 수 없습니다:
# - 실시간 데이터 조회 (날씨, 주가, DB)
# - 외부 시스템 조작 (이메일 발송, 파일 저장)
# - 계산이나 코드 실행
#
# Tool을 등록하면 LLM이 **"이 함수를 호출해야겠다"고 판단**하고, 프레임워크가 실제 함수를 실행합니다.
#
# ### 사용법
#
# ```python
# @agent.tool_plain          # 데코레이터로 도구 등록
# def add(a: int, b: int) -> str:
#     """두 숫자를 더한다."""     # docstring이 LLM에게 도구 설명으로 전달됨
#     return str(a + b)
# ```
#
# - `@agent.tool_plain`: Agent 컨텍스트 없이 독립적으로 동작하는 도구
# - **함수 이름과 docstring**이 LLM에게 전달되어, LLM이 언제 이 도구를 쓸지 판단
# - **타입 힌트** (`a: int, b: int`)가 LLM에게 파라미터 형식을 알려줌
#
# > **실전 활용:** `automation_agent.ipynb`에서 `fetch_github_issues`, `send_slack_message`를, `planner_agent.ipynb`에서 `search_web`, `write_section`을 도구로 등록합니다.

# %%
# Tool이 있는 Agent 만들기: 간단한 계산기 예제
calc_agent = Agent(
    "openai:gpt-5.4",
    instructions="계산이 필요하면 반드시 제공된 도구를 사용하라. 한국어로 답변.",
)


# @agent.tool_plain 데코레이터로 도구 등록
# - 함수 이름(add)과 docstring이 LLM에게 전달됨
# - LLM이 "덧셈이 필요하다"고 판단하면 이 함수를 호출
@calc_agent.tool_plain
def add(a: int, b: int) -> int:
    """두 숫자를 더한다."""
    print(f"  [Tool 호출] add({a}, {b})")
    return a + b


@calc_agent.tool_plain
def multiply(a: int, b: int) -> int:
    """두 숫자를 곱한다."""
    print(f"  [Tool 호출] multiply({a}, {b})")
    return a * b


# Agent 실행 — LLM이 알아서 필요한 도구를 선택하여 호출
result = await calc_agent.run("17과 28을 더하고, 그 결과에 3을 곱해주세요.")
print(f"\n최종 답변: {result.output}")
# Out:
#   [Tool 호출] add(17, 28)
#   [Tool 호출] multiply(45, 3)
#
# 최종 답변: 정답은 **135**입니다.

# %% [markdown]
# ## 6단계: 모두 합치기 — Tool + Structured Output
#
# 지금까지 배운 것을 조합하면 **실전에서 쓸 수 있는 Agent**가 됩니다.
#
# 이 예제에서는 도시 이름을 받아 날씨를 조회(Tool)하고, 구조화된 여행 추천(Structured Output)을 반환하는 Agent를 만듭니다.
#
# ```
# 사용자: "서울 여행 추천해줘"
#    ↓
# Agent가 get_weather("서울") Tool 호출
#    ↓
# LLM이 날씨 정보를 참고해 TravelAdvice 형식으로 응답
#    ↓
# result.output → TravelAdvice(city="서울", weather="맑음", ...)
# ```

# %%
# --- 구조화된 출력 정의 ---
class TravelAdvice(BaseModel):
    city: str              # 도시 이름
    weather: str           # 현재 날씨
    recommended: bool      # 여행 추천 여부
    tips: list[str]        # 여행 팁 목록


# --- Agent 생성: Tool + Structured Output 조합 ---
travel_agent = Agent(
    "openai:gpt-5.4",
    output_type=TravelAdvice,  # 구조화된 형식으로 응답 강제
    instructions=(
        "여행 가이드로서 도시의 날씨를 조회하고 여행 조언을 제공한다. "
        "조회 시점의 현재 날짜를 yyyy-mm-dd 형식으로 나타내고 팁 부분에 포함해서 표시해줘."
        "반드시 get_weather 도구로 날씨를 확인한 후 답변하라. 한국어로 작성."
    ),
)


# --- Tool 등록: 날씨 조회 (Mock) ---
@travel_agent.tool_plain
def get_weather(city: str) -> str:
    """도시의 현재 날씨 정보를 조회한다."""
    # 실제로는 날씨 API를 호출하지만, 여기서는 Mock 데이터 반환
    mock_data = {
        "서울": "맑음, 22°C, 습도 45%",
        "부산": "흐림, 19°C, 오후 비 예보",
        "제주": "맑음, 24°C, 바람 강함",
    }
    weather = mock_data.get(city, f"{city}: 데이터 없음, 약 20°C 예상")
    print(f"  [Tool 호출] get_weather('{city}') → {weather}")
    return weather


# --- 실행 ---
result = await travel_agent.run("제주도 여행을 계획 중이에요. 지금 가도 될까요?")
advice = result.output

print(f"도시: {advice.city}")
print(f"날씨: {advice.weather}")
print(f"추천: {'✅ 추천' if advice.recommended else '❌ 비추천'}")
print("팁:")
for tip in advice.tips:
    print(f"  - {tip}")
# Out:
#   [Tool 호출] get_weather('제주도') → 제주도: 데이터 없음, 약 20°C 예상
# 도시: 제주도
# 날씨: 데이터 없음, 약 20°C 예상
# 추천: ✅ 추천
# 팁:
#   - 2026-03-23 기준으로 현재 상세 날씨 데이터는 없지만, 약 20°C로 예상되어 여행하기에 무난한 편입니다.
#   - 가벼운 겉옷을 챙기세요. 제주도는 바람이 강하게 느껴질 수 있습니다.
#   - 비 예보를 현지에서 다시 확인하고, 우산이나 방수 재킷을 준비하면 좋습니다.
#   - 야외 일정과 실내 일정을 함께 짜두면 날씨 변수에 유연하게 대응할 수 있습니다.

# %% [markdown]
# ## 정리: PydanticAI 핵심 패턴 요약
#
# | 개념 | 역할 | 코드 |
# |------|------|------|
# | **Agent** | LLM을 감싸는 핵심 객체 | `Agent("openai:gpt-5.4")` |
# | **instructions** | 역할·규칙 부여 (시스템 프롬프트) | `Agent(..., instructions="...")` |
# | **output_type** | 응답을 Pydantic 모델로 강제 | `Agent(..., output_type=MyModel)` |
# | **@agent.tool_plain** | LLM이 호출할 수 있는 함수 등록 | `@agent.tool_plain` 데코레이터 |
# | **await agent.run()** | Agent 실행 (Jupyter용) | `result = await agent.run("...")` |
# | **result.output** | 응답 데이터 접근 | `result.output.title` |
#
# ### 다음 단계
#
# 이 개념들이 실전에서 어떻게 조합되는지 확인해보세요:
#
# | 노트북 | Agent 유형 | 핵심 패턴 |
# |--------|-----------|----------|
# | `analysis_agent.ipynb` | 분석형 | output_type만 사용 (Tool 없음) |
# | `automation_agent.ipynb` | 자동화형 | Tool + output_type (고정 순서) |
# | `planner_agent.ipynb` | Planner형 | Tool만 사용 (LLM이 순서 결정) |
